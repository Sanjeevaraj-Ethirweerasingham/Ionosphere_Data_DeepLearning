# %% [markdown]
# Import Data

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/selva86/datasets/master/Ionosphere.csv"
df = pd.read_csv(url)
df.head()
# Out:
#    V1  V2       V3       V4       V5       V6       V7       V8       V9  \
# 0   1   0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708  1.00000
# 1   1   0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597  1.00000
# 2   1   0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062  0.88965
# 3   1   0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000  0.00000
# 4   1   0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255  0.77152
#
#        V10  ...      V26      V27      V28      V29      V30      V31  \
# 0  0.03760  ... -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267
# 1 -0.04549  ... -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626
# 2  0.01198  ... -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436
# 3  0.00000  ...  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682
# 4 -0.16399  ... -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707
#
#        V32      V33      V34  Class
# 0 -0.54487  0.18641 -0.45300      1
# ...

# %%
#Assigning Variables

X = df.drop(["Class"], axis = 1)
y = df["Class"]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %% [markdown]
# # Import Dependencies

# %%
from keras.models import Sequential, load_model
from keras.layers import Dense,Dropout

# %% [markdown]
# # Build model

# %%
model = Sequential()
model.add(Dense(units = 10,activation="relu",input_dim = len(X_train.columns)))
model.add(Dense(units=5,activation = "relu" ))
model.add(Dense(units=1,activation = "sigmoid"))
model.summary
# Out:
# <bound method Model.summary of <keras.engine.sequential.Sequential object at 0x7f0d5695afd0>>

# %%
model.compile(loss = "binary_crossentropy", optimizer = "sgd", metrics = "accuracy")

# %%
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=100, batch_size = 32)                         #epoch = number of times again and again data trained
# Out:
# Epoch 1/100
# 9/9 [==============================] - 1s 25ms/step - loss: 0.7927 - accuracy: 0.3250 - val_loss: 0.7882 - val_accuracy: 0.2817
# Epoch 2/100
# 9/9 [==============================] - 0s 5ms/step - loss: 0.7460 - accuracy: 0.3250 - val_loss: 0.7506 - val_accuracy: 0.3099
# Epoch 3/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.7048 - accuracy: 0.3893 - val_loss: 0.7167 - val_accuracy: 0.4930
# Epoch 4/100
# 9/9 [==============================] - 0s 6ms/step - loss: 0.6699 - accuracy: 0.6179 - val_loss: 0.6949 - val_accuracy: 0.5775
# Epoch 5/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6483 - accuracy: 0.6607 - val_loss: 0.6811 - val_accuracy: 0.5775
# Epoch 6/100
# 9/9 [==============================] - 0s 4ms/step - loss: 0.6325 - accuracy: 0.6929 - val_loss: 0.6705 - val_accuracy: 0.6056
# Epoch 7/100
# ...

# %%
model.save("weights_h5")
# Out:
# WARNING:absl:Found untraced functions such as _update_step_xla while saving (showing 1 of 1). These functions will not be directly callable after loading.
